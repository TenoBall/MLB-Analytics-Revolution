# 13  212  ...  0.397  0.695    91  2133   99   87  13  35   22  1020
# 14  257  ...  0.441  0.768   114  2415  108   56  13  54   33  1093
# 15  272  ...  0.393  0.708    95  2180   94   54  19  44   13  1117
# 16  265  ...  0.403  0.736   105  2222   97   73  26  50   15  1158
# 17  249  ...  0.397  0.708    94  2157  105   88   9  34   10  1089
# 18  262  ...  0.427  0.753   113  2331  119   87  15  53   28  1142
# 19  255  ...  0.455  0.787   118  2488  104   55   7  54   47  1127
# 20  268  ...  0.431  0.759   106  2378   95   60  16  42   19  1133
# 21  245  ...  0.350  0.655    82  1882  123   54  13  32   19  1127
# 22  254  ...  0.390  0.711    96  2115  103   58  48  45   18  1127
# 23  234  ...  0.420  0.740   113  2311  102   89  24  38   29  1120
# 24  239  ...  0.386  0.697    99  2075  103   66  22  52   14  1076
# 25  263  ...  0.378  0.693    96  2056  115   88  25  40   17  1092
# 26  242  ...  0.401  0.714    99  2194  109   46  16  43   10  1042
# 27  245  ...  0.381  0.684   100  2075   92   63  11  40   19  1066
# 28  294  ...  0.427  0.761   108  2354  133   65  35  45   25  1121
# 29  259  ...  0.390  0.694    96  2112  103   57  18  40   11   988
#
# [30 rows x 29 columns]

# %%
# Import Required Libraries
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Define a function to perform linear regression and plot
def plot_regression(df, dependent_var, independent_var):
    X = df[[independent_var]]  # Independent variable
    y = df[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared

    # Plot the scatterplot and regression line
    plt.figure(figsize=(8, 6))
    plt.scatter(X, y, color='blue', label='Data Points')
    plt.plot(X, y_pred, color='red', label='Regression Line')
    plt.title(f"Regression: {dependent_var} vs {independent_var}")
    plt.xlabel(independent_var)
    plt.ylabel(dependent_var)
    plt.legend()

    # Display regression stats below the plot
    plt.figtext(0.15, 0.02, f"Coefficient: {model.coef_[0]:.4f}", fontsize=10)
    plt.figtext(0.15, 0.05, f"Intercept: {model.intercept_:.4f}", fontsize=10)
    plt.figtext(0.15, 0.08, f"R-squared: {r2:.4f}", fontsize=10)

    plt.show()

# List of independent variables
independent_vars = ['HR', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+']

# Generate scatterplots with regression stats for each independent variable
for var in independent_vars:
    plot_regression(df, 'R', var)

# %%
# Import Required Libraries
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Define a function to perform linear regression and return stats
def get_regression_stats(df, dependent_var, independent_var):
    X = df[[independent_var]]  # Independent variable
    y = df[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['HR', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df, 'R', var)
    X = df[[var]]
    y = df['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Scored vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Scored', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Load CSV into a DataFrame
df_2024 = pd.read_csv(r'C:\Users\JTeno\Desktop\Sports Analytics\2024_MLB_Hitting.csv')

# %%
# Define a function to perform linear regression and return stats
def get_regression_stats(df_2024, dependent_var, independent_var):
    X = df_2024[[independent_var]]  # Independent variable
    y = df_2024[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['HR', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df_2024, 'R', var)
    X = df_2024[[var]]
    y = df_2024['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Scored vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Scored', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Load CSV into a DataFrame
df_2023 = pd.read_csv(r'C:\Users\JTeno\Desktop\Sports Analytics\2023_MLB_Hitting.csv')

# %%
# Define a function to perform linear regression and return stats
def get_regression_stats(df_2023, dependent_var, independent_var):
    X = df_2023[[independent_var]]  # Independent variable
    y = df_2023[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['HR', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df_2023, 'R', var)
    X = df_2023[[var]]
    y = df_2023['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Scored vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Scored', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Load CSV into a DataFrame
df_2023_pitching = pd.read_csv(r'C:\Users\JTeno\Desktop\Sports Analytics\2023_MLB_Pitching.csv')

# %%
# Define a function to perform linear regression and return stats
def get_regression_stats(df_2023_pitching, dependent_var, independent_var):
    X = df_2023_pitching[[independent_var]]  # Independent variable
    y = df_2023_pitching[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['H','HR','SO', 'ERA+', 'FIP', 'WHIP']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df_2023_pitching, 'R', var)
    X = df_2023_pitching[[var]]
    y = df_2023_pitching['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Allowed vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Allowed', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Load CSV into a DataFrame
df_2024_pitching = pd.read_csv(r'C:\Users\JTeno\Desktop\Sports Analytics\2024_MLB_Pitching.csv')

# %%
# Define a function to perform linear regression and return stats
def get_regression_stats(df_2024_pitching, dependent_var, independent_var):
    X = df_2024_pitching[[independent_var]]  # Independent variable
    y = df_2024_pitching[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['H','HR','SO', 'ERA+', 'FIP', 'WHIP']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df_2024_pitching, 'R', var)
    X = df_2024_pitching[[var]]
    y = df_2024_pitching['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Allowed vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Allowed', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Load CSV into a DataFrame
df_2025_pitching = pd.read_csv(r'C:\Users\JTeno\Desktop\Sports Analytics\2025_MLB_Pitching.csv')

# %%
# Define a function to perform linear regression and return stats
def get_regression_stats(df_2025_pitching, dependent_var, independent_var):
    X = df_2025_pitching[[independent_var]]  # Independent variable
    y = df_2025_pitching[dependent_var]  # Dependent variable
    model = LinearRegression()  # Initialize the model
    model.fit(X, y)  # Fit the model
    y_pred = model.predict(X)  # Predict the dependent variable
    r2 = r2_score(y, y_pred)  # Calculate R-squared
    return model, y_pred, r2

# List of independent variables
independent_vars = ['H','HR','SO', 'ERA+', 'FIP', 'WHIP']

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the 2D array of axes for easier iteration

# Generate scatterplots with regression stats for each independent variable
for i, var in enumerate(independent_vars):
    ax = axes[i]
    model, y_pred, r2 = get_regression_stats(df_2025_pitching, 'R', var)
    X = df_2025_pitching[[var]]
    y = df_2025_pitching['R']
    
    # Scatterplot and regression line
    ax.scatter(X, y, color='blue', label='Data Points')
    ax.plot(X, y_pred, color='red', label='Regression Line')
    ax.set_title(f"Runs Allowed vs {var}", fontsize=14)
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Runs Allowed', fontsize=12)
    ax.legend()
    
    # Display regression stats on the plot
    ax.text(0.05, 0.95, f"Coef: {model.coef_[0]:.4f}\nIntercept: {model.intercept_:.4f}\nR²: {r2:.4f}",
            transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Adjust layout
plt.tight_layout()
plt.show()
